# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\JESSE\\Downloads\\owid-covid-data.csv")

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df[df.continent.isna()]
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 1266    OWID_AFR       NaN   Africa  2020-01-03          NaN        0.0
# 1267    OWID_AFR       NaN   Africa  2020-01-04         63.0       63.0
# 1268    OWID_AFR       NaN   Africa  2020-01-05         63.0        0.0
# 1269    OWID_AFR       NaN   Africa  2020-01-06         63.0        0.0
# 1270    OWID_AFR       NaN   Africa  2020-01-07         63.0        0.0
# ...          ...       ...      ...         ...          ...        ...
# 316344  OWID_WRL       NaN    World  2023-06-17  768008615.0    23042.0
# 316345  OWID_WRL       NaN    World  2023-06-18  768039567.0    30952.0
# 316346  OWID_WRL       NaN    World  2023-06-19  768185417.0   145850.0
# 316347  OWID_WRL       NaN    World  2023-06-20  768186332.0      915.0
# 316348  OWID_WRL       NaN    World  2023-06-21  768186332.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
# Identify the rows where the location column contains the continent name
continent_rows = df['location'].isin(['Asia', 'Europe', 'Africa', 'North America', 'South America', 'Oceania','World'])

# Create a new column for continent names and populate it

df.loc[continent_rows & df['continent'].isnull(), 'continent'] = df.loc[continent_rows & df['continent'].isnull(), 'location']

df.loc[df.location == 'Africa']
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 1266  OWID_AFR    Africa   Africa  2020-01-03          NaN        0.0
# 1267  OWID_AFR    Africa   Africa  2020-01-04         63.0       63.0
# 1268  OWID_AFR    Africa   Africa  2020-01-05         63.0        0.0
# 1269  OWID_AFR    Africa   Africa  2020-01-06         63.0        0.0
# 1270  OWID_AFR    Africa   Africa  2020-01-07         63.0        0.0
# ...        ...       ...      ...         ...          ...        ...
# 2527  OWID_AFR    Africa   Africa  2023-06-17   13096288.0      903.0
# 2528  OWID_AFR    Africa   Africa  2023-06-18   13096289.0        1.0
# 2529  OWID_AFR    Africa   Africa  2023-06-19   13096524.0      235.0
# 2530  OWID_AFR    Africa   Africa  2023-06-20   13096524.0        0.0
# 2531  OWID_AFR    Africa   Africa  2023-06-21   13096524.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
for i, location in enumerate(df['location']):
    if location == 'European Union':
        df.loc[i, 'continent'] = 'Europe'
df.loc[df['location'] == 'European Union']
# Out:
#        iso_code continent        location        date  total_cases  new_cases  \
# 89802  OWID_EUN    Europe  European Union  2020-01-03          NaN        0.0
# 89803  OWID_EUN    Europe  European Union  2020-01-04          2.0        2.0
# 89804  OWID_EUN    Europe  European Union  2020-01-05          2.0        0.0
# 89805  OWID_EUN    Europe  European Union  2020-01-06          2.0        0.0
# 89806  OWID_EUN    Europe  European Union  2020-01-07          2.0        0.0
# ...         ...       ...             ...         ...          ...        ...
# 91063  OWID_EUN    Europe  European Union  2023-06-17  184389317.0    18126.0
# 91064  OWID_EUN    Europe  European Union  2023-06-18  184391954.0     2637.0
# 91065  OWID_EUN    Europe  European Union  2023-06-19  184393292.0     1338.0
# 91066  OWID_EUN    Europe  European Union  2023-06-20  184394189.0      897.0
# 91067  OWID_EUN    Europe  European Union  2023-06-21  184394189.0        0.0
#
# ...

# %%
df.continent.fillna('Class',inplace= True)

# %%
df.loc[df.continent == 'Class']
# Out:
#         iso_code continent             location        date  total_cases  \
# 121452  OWID_HIC     Class          High income  2020-01-03          NaN
# 121453  OWID_HIC     Class          High income  2020-01-04          4.0
# 121454  OWID_HIC     Class          High income  2020-01-05          4.0
# 121455  OWID_HIC     Class          High income  2020-01-06          4.0
# 121456  OWID_HIC     Class          High income  2020-01-07          4.0
# ...          ...       ...                  ...         ...          ...
# 305045  OWID_UMC     Class  Upper middle income  2023-06-17  244061214.0
# 305046  OWID_UMC     Class  Upper middle income  2023-06-18  244083270.0
# 305047  OWID_UMC     Class  Upper middle income  2023-06-19  244105055.0
# 305048  OWID_UMC     Class  Upper middle income  2023-06-20  244105126.0
# 305049  OWID_UMC     Class  Upper middle income  2023-06-21  244105126.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df.to_csv('owid-covid-data-clean.csv')
